# %%
import pandas as pd

# %%
cola_data = pd.read_excel("data/Cola.xlsx")
cola_data
# Out:
#      Data provided by SimFin  \
# 0                        NaN
# 1    Profit & Loss statement
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ..                       ...
# 98                       NaN
# 99                       NaN
# 100                      NaN
# 101                      NaN
# 102                      NaN
#
#                                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                       in million USD     FY '09     FY '10
# 3                               NET OPERATING REVENUES      30990      35119
# 4                                   Cost of goods sold      11088      12693
# ..                                                 ...        ...        ...
# 98   Effect of exchange rate changes on cash and ca...        576       -166
# 99   Cash Provided by (Used in) Investing Activitie...        NaN        NaN
# 100  Cash Provided by (Used in) Financing Activitie...        NaN        NaN
# 101  Net Cash Provided by (Used in) Discontinued Op...        NaN        NaN
# 102            Net increase (decrease) during the year       2320       1496
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2       FY '11     FY '12     FY '13     FY '14     FY '15     FY '16
# 3        46542      48017      46854      45998      44294      41863
# 4        18215      19053      18421      17889      17482      16465
# ..         ...        ...        ...        ...        ...        ...
# 98        -430       -255       -611       -934       -878         -6
# 99         NaN        NaN        NaN        NaN          0          0
# 100        NaN        NaN        NaN        NaN          0          0
# 101        NaN        NaN        NaN        NaN          0          0
# 102       4286      -4361       1972      -1456      -1649       1246
#
#     Unnamed: 10 Unnamed: 11
# 0           NaN         NaN
# 1           NaN         NaN
# 2        FY '17      FY '18
# 3         35410       31856
# 4         13255       11770
# ..          ...         ...
# 98          241        -262
# 99          -58        -421
# 100         -38         205
# 101          15          91
# 102       -2477        2945
#
# [103 rows x 12 columns]

# %%
balance = cola_data.iloc[22:64, 1:]

balance = balance.T
balance.columns = [
    "Financial Year",
    "Assets",
    "Cash and cash equivalents",
    "Short-term investments",
    "Total cash, cash equivalents and short-term investments",
    "Marketable securities",
    "Trade accounts receivable, less allowances",
    "Inventories",
    "Prepaid expenses and other assets",
    "Assets held for sale",
    "Assets held for sale",
    "Total current assets",
    "Equity method investments",
    "Other investments",
    "Other assets",
    "Property, plant and equipment - net",
    "Deferred income tax assets",
    "TRADEMARKS WITH INDEFINITE LIVES",
    "BOTTLERS' FRANCHISE RIGHTS WITH INDEFINITE LIVES",
    "Goodwill",
    "Other intangible assets",
    "Total assets",
    "Liabilities",
    "Accounts payable and accrued expenses",
    "Loans and notes payable",
    "Current maturities of long-term debt",
    "Accrued income taxes",
    "Liabilities held for sale",
    "Liabilities Held for Sale, Discontinued Operations",
    "Total current liabilities",
    "Long-term debt",
    "Other liabilities",
    "Deferred income taxes",
    "Common stock",
    "Capital surplus",
    "Reinvested earnings",
    "Accumulated other comprehensive income (loss)",
    "Treasury stock, at cost",
    "EQUITY ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY",
    "Equity attributable to noncontrolling interests",
    "Total equity",
    "Total liabilities and equity",
]
balance.reset_index(drop=True, inplace=True)
balance = balance.iloc[1:].reset_index(drop=True)
balance
# Out:
#   Financial Year Assets Cash and cash equivalents Short-term investments  \
# 0         FY '09    NaN                      7021                   2130
# 1         FY '10    NaN                      8517                   2682
# 2         FY '11    NaN                     12803                   1088
# 3         FY '12    NaN                      8442                   5017
# 4         FY '13    NaN                     10414                   6707
# 5         FY '14    NaN                      8958                   9052
# 6         FY '15    NaN                      7309                   8322
# 7         FY '16    NaN                      8555                   9595
# 8         FY '17    NaN                      6006                   9352
# 9         FY '18    NaN                      8926                   2025
#
#   Total cash, cash equivalents and short-term investments  \
# 0                                               9151
# 1                                              11199
# 2                                              13891
# 3                                              13459
# 4                                              17121
# 5                                              18010
# 6                                              15631
# 7                                              18150
# 8                                              15358
# 9                                              10951
#
#   Marketable securities Trade accounts receivable, less allowances  \
# 0                    62                                       3758
# 1                   138                                       4430
# 2                   144                                       4920
# 3                  3092                                       4759
# 4                  3147                                       4873
# 5                  3665                                       4466
# 6                  4269                                       3941
# 7                  4051                                       3856
# 8                  5317                                       3667
# 9                  5013                                       3396
#
#   Inventories Prepaid expenses and other assets Assets held for sale  ...  \
# 0        2354                              2226                  NaN  ...
# 1        2650                              3162                  NaN  ...
# 2        3092                              3450                    0  ...
# 3        3264                              2781                 2973  ...
# 4        3277                              2886                    0  ...
# 5        3100                              3066                  679  ...
# 6        2902                              2752                 3900  ...
# 7        2675                              2481                    0  ...
# 8        2655                              2000                 7329  ...
# 9        2766                              1962                 6546  ...
#
#   Deferred income taxes Common stock Capital surplus Reinvested earnings  \
# 0                  1580          880            8537               41537
# 1                  4261          880           10057               49278
# 2                  4694         1760           10332               53621
# 3                  4981         1760           11379               58045
# 4                  6152         1760           12276               61660
# 5                  5636         1760           13154               63408
# 6                  4691         1760           14016               65018
# 7                  3753         1760           14993               65502
# 8                  2522         1760           15864               60430
# 9                  1933         1760           16520               63234
#
#   Accumulated other comprehensive income (loss) Treasury stock, at cost  \
# 0                                          -757                  -25398
# 1                                         -1450                  -27762
# 2                                         -2774                  -31304
# 3                                         -3385                  -35009
# 4                                         -3432                  -39091
# 5                                         -5777                  -42225
# 6                                        -10174                  -45066
# 7                                        -11205                  -47988
# 8                                        -10305                  -50677
# 9                                        -12814                  -51719
#
#   EQUITY ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY  \
# 0                                              24799
# 1                                              31003
# 2                                              31635
# 3                                              32790
# 4                                              33173
# 5                                              30320
# 6                                              25554
# 7                                              23062
# 8                                              17072
# 9                                              16981
#
#   Equity attributable to noncontrolling interests Total equity  \
# 0                                             547        25346
# 1                                             314        31317
# 2                                             286        31921
# 3                                             378        33168
# 4                                             267        33440
# 5                                             241        30561
# 6                                             210        25764
# 7                                             158        23220
# 8                                            1905        18977
# 9                                            2077        19058
#
#   Total liabilities and equity
# 0                        48671
# 1                        72921
# 2                        79974
# 3                        86174
# 4                        90055
# 5                        92023
# 6                        89996
# 7                        87270
# 8                        87896
# 9                        83216
#
# [10 rows x 42 columns]

# %%
cols = [
    "Assets",
    "Cash and cash equivalents",
    "Short-term investments",
    "Total cash, cash equivalents and short-term investments",
    "Marketable securities",
    "Trade accounts receivable, less allowances",
    "Inventories",
    "Prepaid expenses and other assets",
    "Assets held for sale",
    "Assets held for sale",
    "Total current assets",
    "Equity method investments",
    "Other investments",
    "Other assets",
    "Property, plant and equipment - net",
    "Deferred income tax assets",
    "TRADEMARKS WITH INDEFINITE LIVES",
    "BOTTLERS' FRANCHISE RIGHTS WITH INDEFINITE LIVES",
    "Goodwill",
    "Other intangible assets",
    "Total assets",
    "Liabilities",
    "Accounts payable and accrued expenses",
    "Loans and notes payable",
    "Current maturities of long-term debt",
    "Accrued income taxes",
    "Liabilities held for sale",
    "Liabilities Held for Sale, Discontinued Operations",
    "Total current liabilities",
    "Long-term debt",
    "Other liabilities",
    "Deferred income taxes",
    "Common stock",
    "Capital surplus",
    "Reinvested earnings",
    "Accumulated other comprehensive income (loss)",
    "Treasury stock, at cost",
    "EQUITY ATTRIBUTABLE TO SHAREOWNERS OF THE COCA-COLA COMPANY",
    "Equity attributable to noncontrolling interests",
    "Total equity",
    "Total liabilities and equity",
]


balance[cols] = balance[cols].apply(pd.to_numeric).astype("Int64")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 46
#      42     "Total liabilities and equity",
#      43 ]
#      44
#      45
# ---> 46 balance[cols] = balance[cols].apply(pd.to_numeric).astype("Int64")
#
# File d:\PROITBRIDGE_Learning\.venv\Lib\site-packages\pandas\core\frame.py:4660, in DataFrame.__setitem__(self, key, value)
#    4656
#    4657         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
#    4662             self._set_item_frame_value(key, value)
#    4663         elif (
#
# File d:\PROITBRIDGE_Learning\.venv\Lib\site-packages\pandas\core\frame.py:4701, in DataFrame._setitem_array(self, key, value)
#    4697
#    4698         elif isinstance(value, DataFrame):
#    4699             check_key_length(self.columns, key, value)
#    4700             for k1, k2 in zip(key, value.columns, strict=False):
# -> 4701                 self[k1] = value[k2]
#    4702
#    4703         elif not is_list_like(value):
#    4704             for col in key:
#
# File d:\PROITBRIDGE_Learning\.venv\Lib\site-packages\pandas\core\frame.py:4662, in DataFrame.__setitem__(self, key, value)
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
# -> 4662             self._set_item_frame_value(key, value)
#    4663         elif (
#    4664             is_list_like(value)
#    4665             and not self.columns.is_unique
#
# File d:\PROITBRIDGE_Learning\.venv\Lib\site-packages\pandas\core\frame.py:4786, in DataFrame._set_item_frame_value(self, key, value)
#    4782             loc = self.columns.get_loc(key)
#    4783             cols = self.columns[loc]
#    4784             len_cols = 1 if is_scalar(cols) or isinstance(cols, tuple) else len(cols)
#    4785             if len_cols != len(value.columns):
# -> 4786                 raise ValueError("Columns must be same length as key")
#    4787
#    4788             # align right-hand-side columns if self.columns
#    4789             # is multi-index and self[key] is a sub-frame
#
# ValueError: Columns must be same length as key
