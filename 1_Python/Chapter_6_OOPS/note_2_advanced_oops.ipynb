# %% [markdown]
# ## Advanced OOps Concepts

# %% [markdown]
# #### Usercase: I want to hide sensitive data so that other's can't directly acdess or change it

# %%
# class SecureUser:
#     name = None
#     atm_pin = None

#     def get_pin(attempt):
#         return attempt == atm_pin

#     def deopsit_cash():
#         pass
    
#     def cash_withdrawal():
#         pass

# %%
# user_data = SecureUser()

# %%
# user_data.name = "Derin"
# user_data.atm_pin = 1111

# %%
# print(user_data.name)
# print(user_data.atm_pin)

# %%
# user_data.get_pin(2222)

# %%
# user_data_2 = SecureUser()
# print(user_data_2.atm_pin)

# %%
# user_data_3 = SecureUser(name="Sample", atm_pin=123)
# print(user_data_3.name)
# print(user_data_3.atm_pin)

# %% [markdown]
# ### with __init__ and Self

# %%
class SecureUser:

    def __init__(self, name, atm_pin):
        self.name = name
        self.__atm_pin = atm_pin

    def get_pin(self,attempt):
        return attempt == self.atm_pin

    def deopsit_cash():
        pass

    def cash_withdrawal():
        pass

# %%
derin_data = SecureUser(name="Derin", atm_pin=1234)

# %%
derin_data.get_pin(1235)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 derin_data.get_pin(1235)
#
# Cell In[53], line 8, in SecureUser.get_pin(self, attempt)
#       7     def get_pin(self,attempt):
# ----> 8         return attempt == self.atm_pin
#
# AttributeError: 'SecureUser' object has no attribute 'atm_pin'

# %%
derin_data.__atm_pin
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 derin_data.__atm_pin
#
# AttributeError: 'SecureUser' object has no attribute '__atm_pin'
