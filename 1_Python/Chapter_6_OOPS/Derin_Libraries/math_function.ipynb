# %% [markdown]
# #### Terminology Alert
# - Paremeter - While creating the function, you create parameters
# - Attributes - While calling the function, you pass arguments

# %% [markdown]
# #### Difference between return and print
# - return - impacts the original data when function is called
# - print - it won't impact the original data, but just prints

# %%
import importlib
import math_function as mf

importlib.reload(mf)
# Out:
# <module 'math_function' from 'd:\\PROITBRIDGE_Learning\\1_Python\\Chapter_6_OOPS\\Derin_Libraries\\math_function.py'>

# %%
mf.addition(23)
# Out:
# 24
