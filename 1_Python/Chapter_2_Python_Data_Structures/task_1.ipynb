# %% [markdown]
# # Task 1
# #### One Function Example for all Python Data Structures

# %% [markdown]
# ---

# %% [markdown]
# ## 1. List

# %%
cart = ["Milk", "Bread", "Eggs"]
print(f"Cart: {cart}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs']

# %% [markdown]
# #### 1.1. append()

# %%
print(f"Cart: {cart}")
cart.append("Cheese")
print(f"Cart: {cart}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs']
# Cart: ['Milk', 'Bread', 'Eggs', 'Cheese']

# %% [markdown]
# #### 1.2 insert()

# %%
print(f"Cart: {cart}")
cart.insert(3, "Juice")
print(f"Cart: {cart}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs', 'Cheese']
# Cart: ['Milk', 'Bread', 'Eggs', 'Juice', 'Cheese']

# %% [markdown]
# #### 1.3 extend()

# %%
print(f"Cart: {cart}")
cart.extend(["rice", "carrot"])
print(f"Cart: {cart}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs', 'Juice', 'Cheese']
# Cart: ['Milk', 'Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot']

# %% [markdown]
# #### 1.4 count()

# %%
cart.extend(["Bread", "Eggs"])
print(f"Cart: {cart}")
count = cart.count('Bread')
print(f"Count of Bread: {count}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread', 'Eggs']
# Count of Bread: 2

# %% [markdown]
# #### 1.5 index()

# %%
print(f"Cart: {cart}")
index = cart.index("Eggs")
print(f"Index of Eggs: {index}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread', 'Eggs']
# Index of Eggs: 2

# %% [markdown]
# #### 1.6 remove()

# %%
print(f"Cart: {cart}")
cart.remove("Milk")
print(f"Cart: {cart}")
# Out:
# Cart: ['Milk', 'Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread', 'Eggs']
# Cart: ['Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread', 'Eggs']

# %% [markdown]
# #### 1.7 pop()

# %%
print(f"Cart: {cart}")
popped_item = cart.pop()
print(f"Popped Item: {popped_item}")
print(f"Cart: {cart}")
# Out:
# Cart: ['Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread', 'Eggs']
# Popped Item: Eggs
# Cart: ['Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread']

# %% [markdown]
# #### 1.8 sort()

# %%
print(f"Cart: {cart}")
cart.sort()
print(f"Cart: {cart}")
# Out:
# Cart: ['Bread', 'Eggs', 'Juice', 'Cheese', 'rice', 'carrot', 'Bread']
# Cart: ['Bread', 'Bread', 'Cheese', 'Eggs', 'Juice', 'carrot', 'rice']

# %% [markdown]
# #### 1.9 reverse()

# %%
print(f"Cart: {cart}")
cart.reverse()
print(f"Cart: {cart}")
# Out:
# Cart: ['Bread', 'Bread', 'Cheese', 'Eggs', 'Juice', 'carrot', 'rice']
# Cart: ['rice', 'carrot', 'Juice', 'Eggs', 'Cheese', 'Bread', 'Bread']

# %% [markdown]
# #### 1.10 copy()

# %%
copy_cart = cart.copy()
print(f"Cart: {cart}")
print(f"Cart: {copy_cart}")
# Out:
# Cart: ['rice', 'carrot', 'Juice', 'Eggs', 'Cheese', 'Bread', 'Bread']
# Cart: ['rice', 'carrot', 'Juice', 'Eggs', 'Cheese', 'Bread', 'Bread']

# %% [markdown]
# #### 1.11 clear()

# %%
print(f"Cart: {cart}")
cart.clear()
print(f"Cart: {cart}")
# Out:
# Cart: ['rice', 'carrot', 'Juice', 'Eggs', 'Cheese', 'Bread', 'Bread']
# Cart: []

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Set

# %%
coding_club = {"Derin", "Girish", "Adarsh", "Aditya"}
music_club = {"Adarsh", "Monish", "Girish"}
print(f"Coding Club: {coding_club}")
print(f"Music Club: {music_club}")
# Out:
# Coding Club: {'Adarsh', 'Aditya', 'Derin', 'Girish'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}

# %% [markdown]
# #### 2.1 add()

# %%
print(f"Coding Club before adding: {coding_club}")
coding_club.add("Deena")
print(f"Coding Club after adding: {coding_club}")
# Out:
# Coding Club before adding: {'Adarsh', 'Aditya', 'Derin', 'Girish'}
# Coding Club after adding: {'Adarsh', 'Girish', 'Derin', 'Aditya', 'Deena'}

# %% [markdown]
# #### 2.2 update()

# %%
print(f"Coding Club before update: {coding_club}")
coding_club.update({"Harsha", "Grunath"})
print(f"Coding Club after update: {coding_club}")
# Out:
# Coding Club before update: {'Adarsh', 'Girish', 'Derin', 'Aditya', 'Deena'}
# Coding Club after update: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}

# %% [markdown]
# #### 2.3 union()

# %%
print(f"Coding Club: {coding_club}")
print(f"Music Club: {music_club}")
all_student = coding_club.union(music_club)
print(f"All Student: {all_student}")
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# All Student: {'Adarsh', 'Girish', 'Monish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}

# %% [markdown]
# #### 2.4 intersection()

# %%
print(f"Coding Club: {coding_club}")
print(f"Music Club: {music_club}")
common_student = coding_club.intersection(music_club)
print(f"Common Student: {common_student}")
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# Common Student: {'Adarsh', 'Girish'}

# %% [markdown]
# #### 2.5 intersection_update()

# %%
all_student_1 = all_student.copy()
print(f"All Student Before Insersection Update: {all_student_1}")
print(f"Music Club: {music_club}")
all_student_1.intersection_update(music_club)
print(f"All Student After Insersection Update: {all_student_1}")
# Out:
# All Student Before Insersection Update: {'Adarsh', 'Girish', 'Monish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# All Student After Insersection Update: {'Adarsh', 'Monish', 'Girish'}

# %% [markdown]
# #### 2.6 difference()

# %%
print(f"Coding Club: {coding_club}")
print(f"Music club: {music_club}")
only_coding_club = coding_club.difference(music_club)
print(f"Only Coding Club: {only_coding_club}")
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music club: {'Adarsh', 'Girish', 'Monish'}
# Only Coding Club: {'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}

# %% [markdown]
# #### 2.7 difference_update()

# %%
all_student_1 = all_student.copy()
print(f"All Student before Difference Update: {all_student_1}")
print(f"Music Club: {music_club}")
all_student_1.difference_update(music_club)
print(f"All Student after Difference Update: {all_student_1}")
# Out:
# All Student before Difference Update: {'Adarsh', 'Girish', 'Monish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# All Student after Difference Update: {'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}

# %% [markdown]
# #### 2.8 symmetric_difference()

# %%
print(f"Coding Club: {coding_club}")
print(f"Music Club: {music_club}")
unique_student = coding_club.symmetric_difference(music_club)
print(f"Unique Student: {unique_student}")
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# Unique Student: {'Monish', 'Harsha', 'Derin', 'Grunath', 'Aditya', 'Deena'}

# %% [markdown]
# #### 2.9 summertic_difference_update()

# %%
coding_club_1 = coding_club.copy()
print(f"Coding Club before symmetric differnce update : {coding_club_1}")
coding_club_1.symmetric_difference_update(music_club)
print(f"Music Club: {music_club}")
print(f"Coding Club after symmetric differnce update : {coding_club_1}")
# Out:
# Coding Club before symmetric differnce update : {'Adarsh', 'Aditya', 'Girish', 'Deena', 'Derin', 'Harsha', 'Grunath'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# Coding Club after symmetric differnce update : {'Aditya', 'Monish', 'Deena', 'Derin', 'Harsha', 'Grunath'}

# %% [markdown]
# #### 2.10 isdisjoint()

# %%
sports_club = {"nandha", "rishi"}
print(f"Coding Club: {coding_club}")
print(f"Music Club: {music_club}")
print(f"Sports Club: {sports_club}")

print(coding_club.isdisjoint(music_club))

print(coding_club.isdisjoint(sports_club))
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# Sports Club: {'nandha', 'rishi'}
# False
# True

# %% [markdown]
# #### 2.11 issubset()

# %%
ds_club = {"Derin", "Girish", "Aditya"}
print(f"Coding Club: {coding_club}")
print(f"DS Club: {ds_club}")
print(f"Sports Club: {sports_club}")

print(ds_club.issubset(coding_club))
print(sports_club.issubset(coding_club))
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# DS Club: {'Aditya', 'Derin', 'Girish'}
# Sports Club: {'nandha', 'rishi'}
# True
# False

# %% [markdown]
# #### 2.12 issuperset()

# %%
print(f"Coding Club: {coding_club}")
print(f"DS Club: {ds_club}")
print(f"Sports Club: {sports_club}")

print(coding_club.issuperset(ds_club))
print(coding_club.issuperset(sports_club))
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# DS Club: {'Aditya', 'Derin', 'Girish'}
# Sports Club: {'nandha', 'rishi'}
# True
# False

# %% [markdown]
# #### 2.13 remove()

# %%
print(f"Coding Club: {coding_club}")
coding_club.remove("Aditya")
print(f"Coding Club after remove: {coding_club}")
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Aditya', 'Deena'}
# Coding Club after remove: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Deena'}

# %% [markdown]
# #### 2.14 discard()

# %%
print(f"Coding Club: {coding_club}")
coding_club.discard("Harsha")
print(f"Coding Club after discard: {coding_club}")
# Out:
# Coding Club: {'Adarsh', 'Girish', 'Derin', 'Harsha', 'Grunath', 'Deena'}
# Coding Club after discard: {'Adarsh', 'Girish', 'Derin', 'Grunath', 'Deena'}

# %% [markdown]
# #### 2.15 pop()

# %%
print(f"coding_club: {coding_club}")
popped_stuend = coding_club.pop()
print(f"Popped Student: {popped_stuend}")
# Out:
# coding_club: {'Adarsh', 'Girish', 'Derin', 'Grunath', 'Deena'}
# Popped Student: Adarsh

# %% [markdown]
# #### 2.16 copy()

# %%
copy_music_club = music_club.copy()
print(f"Music Club: {music_club}")
print(f"Music Club Copy: {copy_music_club}")
# Out:
# Music Club: {'Adarsh', 'Girish', 'Monish'}
# Music Club Copy: {'Adarsh', 'Girish', 'Monish'}

# %%
print(f"Music club: {music_club}")
music_club.clear()
print(f"Music Club: {music_club}")
# Out:
# Music club: {'Adarsh', 'Girish', 'Monish'}
# Music Club: set()

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Tuple

# %%
marks = (89, 99, 74, 99, 100)
print(f"Marks: {marks}")
# Out:
# Marks: (89, 99, 74, 99, 100)

# %% [markdown]
# #### 3.1 count()

# %%
count = marks.count(99)
print(f"Count of mark 99 is {count}")
# Out:
# Count of mark 99 is 2

# %%
index = marks.index(100)
print(f"Index of mark 74 is {index}")
# Out:
# Index of mark 74 is 4

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Dictionary

# %%
student_data = {
    "name" : "Derin",
    "age" : 22,
    "course" : "CSE"
}

print(f"Student Data : {student_data}")
# Out:
# Student Data : {'name': 'Derin', 'age': 22, 'course': 'CSE'}

# %% [markdown]
# #### 4.1 get()

# %%
name = student_data.get("name")
age = student_data.get("age")
print(f"Name: {name}")
print(f"Age: {age}")
# Out:
# Name: Derin
# Age: 22

# %% [markdown]
# #### 4.2 keys()

# %%
print(f"Keys: {student_data.keys()}")
# Out:
# Keys: dict_keys(['name', 'age', 'course'])

# %% [markdown]
# #### 4.3 values()

# %%
print(f"Values: {student_data.values()}")
# Out:
# Values: dict_values(['Derin', 22, 'CSE'])

# %% [markdown]
# #### 4.4 items()

# %%
print(f"Items: {student_data.items()}")
# Out:
# Items: dict_items([('name', 'Derin'), ('age', 22), ('course', 'CSE')])

# %% [markdown]
# #### 4.5 update()

# %%
print(f"Student Data: {student_data}")
student_data.update({"city" : "Bangalore"})
print(f"Student Data: {student_data}")
# Out:
# Student Data: {'name': 'Derin', 'age': 22, 'course': 'CSE'}
# Student Data: {'name': 'Derin', 'age': 22, 'course': 'CSE', 'city': 'Bangalore'}

# %% [markdown]
# #### 4.6 setdefault()

# %%
print(f"Student Data: {student_data}")
student_data.setdefault("grade", "A")
print(f"Student Data: {student_data}")
student_data.setdefault("city", "Chennai")
print(f"Student Data: {student_data}")
# Out:
# Student Data: {'name': 'Derin', 'age': 22, 'course': 'CSE', 'city': 'Bangalore'}
# Student Data: {'name': 'Derin', 'age': 22, 'course': 'CSE', 'city': 'Bangalore', 'grade': 'A'}
# Student Data: {'name': 'Derin', 'age': 22, 'course': 'CSE', 'city': 'Bangalore', 'grade': 'A'}

# %% [markdown]
# #### 4.7 pop()

# %%
print(f"Student Student: {student_data}")
poped_item = student_data.pop("course")
print(f"Poped Value: {poped_item}")
print(f"Student Student: {student_data}")
# Out:
# Student Student: {'name': 'Derin', 'age': 22, 'course': 'CSE', 'city': 'Bangalore', 'grade': 'A'}
# Poped Value: CSE
# Student Student: {'name': 'Derin', 'age': 22, 'city': 'Bangalore', 'grade': 'A'}

# %% [markdown]
# #### 4.8 popitem()

# %%
print(f"Student Data: {student_data}")
poped_item = student_data.popitem()
print(f"Poped Value: {poped_item}")
print(f"Student Data: {student_data}")
# Out:
# Student Data: {'name': 'Derin', 'age': 22, 'city': 'Bangalore', 'grade': 'A'}
# Poped Value: ('grade', 'A')
# Student Data: {'name': 'Derin', 'age': 22, 'city': 'Bangalore'}

# %% [markdown]
# #### 4.9 copy()

# %%
student_data_copy = student_data.copy()
print(f"Student Data: {student_data}")
print(f"Student Data Copy: {student_data_copy}")
# Out:
# Student Data: {'name': 'Derin', 'age': 22, 'city': 'Bangalore'}
# Student Data Copy: {'name': 'Derin', 'age': 22, 'city': 'Bangalore'}

# %% [markdown]
# #### 4.10 fromkeys()

# %%
marks_tuple = ("tamil", "english", "math", "science", "social")
mark = 35
marks_dictionary =  dict.fromkeys(marks_tuple, mark)
print(f"Marks: {marks_dictionary}")
# Out:
# Marks: {'tamil': 35, 'english': 35, 'math': 35, 'science': 35, 'social': 35}

# %% [markdown]
# #### 4.11 clear()

# %%
print(f"Student Data: {student_data}")
student_data.clear()
print(f"Student Data: {student_data}")
# Out:
# Student Data: {'name': 'Derin', 'age': 22, 'city': 'Bangalore'}
# Student Data: {}

# %% [markdown]
# ---
